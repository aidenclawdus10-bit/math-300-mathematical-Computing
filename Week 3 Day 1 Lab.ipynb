# %% [markdown]
# # Week 3 Day 1 Lab
#
# This week we are going to cover data visualization libraries. We will focus a lot on techniques to make "nice" diagrams and what message we want to send to the reader.
#
# ### The Matplotlib Library
#
# Matplotlib is Python's standard plotting library. Virtually any type of diagram you require, Matplotlib has it. Moreover, there are many features you can tweak for your specific plot. Let's cover some today. For a full list of what Matplotlib has to offer, see the documentation here: https://matplotlib.org/stable/api/index.html.
#
# ### Problem 1
#
# 1. Install `matplotlib`
# 2. Import `matplotlib.pyplot` under variable name `plt`
# 3. Import `numpy` under variable name `np`

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %%
 # type import code here
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Problem 2
#
# Given the following data
#
# ```python
#     heartrate = [68,70,71, 71,
#                  71, 74, 75, 78,
#                  80, 79, 75, 70, 68]
#     time = ['12:00', '12:05', '12:10', '12:15',
#             '12:20', '12:25', '12:30', '12:35',
#             '12:40', '12:45', '12:50', '12:55', '1:00']
# ```
# Use `plt.scatter()` to plot `time` along the x-axis and `heartrate` along the y-axis.

# %%
x = [68,70,71, 71, 71, 74, 75, 78, 80, 79, 75, 70, 68]
y = ['12:00', '12:05', '12:10', '12:15', '12:20', '12:25', '12:30', '12:35','12:40', '12:45', '12:50', '12:55', '1:00']
plt.scatter(y, x)

# %% [markdown]
# ### Problem 3
# Without adding any extra features (simply using `plt.scatter()`), the plot can be very uninformative.
#
# Let's add some tweaks:
# - We will rotate the x-labels so they aren't horizontal
# - Add an x-axis label and a y-axis label
# - Add an informative title
#
# We will use the following:
# - `plt.xticks(rotation=45)`
# - `plt.xlabel('x_axis_name_of_your_choice')` and `plt.ylabel('y_axis_name_of_your_choice')`
# - `plt.title('title_of_your_choice')`
#
# To implement these, run all of these <i> in the same cell </i>.

# %%
x = [68,70,71, 71, 71, 74, 75, 78, 80, 79, 75, 70, 68]
y = ['12:00', '12:05', '12:10', '12:15', '12:20', '12:25', '12:30', '12:35','12:40', '12:45', '12:50', '12:55', '1:00']
plt.scatter(y, x)
plt.xticks(rotation=45)
plt.xlabel('time')
plt.ylabel('heartrate')
plt.title('Heartrate Over Time')
# Out:
# Text(0.5, 1.0, 'Heartrate Over Time')

# %% [markdown]
# ### Problem 4
#
# Recall:
# - `np.linspace(start, stop, slice_count)` produces `slice_count` amount of numbers between `start` and `stop`
# - `np.sin(x)` calculates $\sin(x)$ where `x` is a single number or numpy array (which `np.linspace` produces)
# - `np.pi` produces the irrational number $\pi\approx 3.14159$
#
# Using these functions,
# 1. make a list `xdata` that contains 100 evenly spaced points between 0 and $2\pi$
# 2. make a list `ysindata` that contains $\sin(x)$ for each $x$ in `xdata`
# 3. use `plt.plot(xdata, ysindata)` to plot the data

# %%
np.linspace(0,2*np.pi, 100)
x_data = []
y_data = []
for i in np.linspace(0,2*np.pi, 100):
    x_data.append(i)
    y_data.append(np.sin(i))
plt.plot(x_data, y_data)

# %% [markdown]
# ### Problem 5
# Using the same `xdata` from above, make a list `ycosdata` that contains $\cos(x)$ for each $x$ in `xdata`.
#
# We can plot `xdata` against both `ycosdata` and `ysindata` simultaneously. To do so, use `plt.plot(xdata, ysindata)` and `plt.plot(xdata, ycosdata)` in the same cell.

# %%
np.linspace(0,2*np.pi, 100)
x_data = []
y_data = []
cos_data = []
for i in np.linspace(0,2*np.pi, 100):
    x_data.append(i)
    y_data.append(np.sin(i))
    cos_data.append(np.cos(i))
plt.plot(x_data, y_data)
plt.plot(x_data, cos_data)

# %% [markdown]
# So far, these just look like two curves. To differentiate between the two curves, we can use the `label` attribute and a legend.
#
# All in one cell:
# 1. Instead of `plt.plot(xdata, ysindata)`, use `plt.plot(xdata, ysindata, label='Sine')`. Likewise with the cosine data.
# 2. Use `plt.legend()` to plot the legend.

# %%
np.linspace(0,2*np.pi, 100)
x_data = []
y_data = []
cos_data = []
for i in np.linspace(0,2*np.pi, 100):
    x_data.append(i)
    y_data.append(np.sin(i))
    cos_data.append(np.cos(i))
plt.plot(x_data, y_data, label='sin(x)')
plt.plot(x_data, cos_data, label='cos(x)')
plt.legend()

# %% [markdown]
# Now we know which curve is which! But, we don't have axis labels or a title. Add these in the following cell.

# %%
np.linspace(0,2*np.pi, 100)
x_data = []
y_data = []
cos_data = []
for i in np.linspace(0,2*np.pi, 100):
    x_data.append(i)
    y_data.append(np.sin(i))
    cos_data.append(np.cos(i))
plt.plot(x_data, y_data, label='sin(x)')
plt.plot(x_data, cos_data, label='cos(x)')
plt.legend()
plt.xlabel('time')
plt.ylabel('heartrate')
plt.title('Heartrate Over Time')
# Out:
# Text(0.5, 1.0, 'Heartrate Over Time')

# %% [markdown]
# ### Problem 6
# Consider the following data set that contains values between 0 and 7 (inclusive):
#
# ```python
# data = [4, 2, 4, 5, 0, 2, 4, 4, 3, 6, 1, 4, 5, 3, 1, 2, 3, 3, 4, 6, 4, 5,
#        2, 6, 5, 2, 3, 3, 4, 4, 2, 1, 4, 3, 2, 3, 6, 7, 3, 3, 3, 4, 2, 4,
#        3, 2, 2, 2, 4, 3, 2, 3, 4, 2, 5, 5, 3, 3, 5, 3, 2, 6, 2, 2, 4, 4,
#        2, 3, 4, 5, 2, 3, 4, 6, 2, 5, 2, 4, 5, 1, 5, 3, 3, 5, 0, 2, 3, 5,
#        3, 2, 2, 5, 7, 5, 3, 3, 4, 2, 4, 4]
# ```
# 1. Write a function that will take in `data` and outputs a list `counts` containing the number of each value in `data`. (Hint: `data.count(i)` gives you the count of `i` in `data`)

# %%
data = [4, 2, 4, 5, 0, 2, 4, 4, 3, 6, 1, 4, 5, 3, 1, 2, 3, 3, 4, 6, 4, 5,2, 6, 5, 2, 3, 3, 4, 4, 2, 1, 4, 3, 2, 3, 6, 7, 3, 3, 3, 4, 2, 4,3, 2, 2, 2, 4, 3, 2, 3, 4, 2, 5, 5, 3, 3, 5, 3, 2, 6, 2, 2, 4, 4,2, 3, 4, 5, 2, 3, 4, 6, 2, 5, 2, 4, 5, 1, 5, 3, 3, 5, 0, 2, 3, 5,3, 2, 2, 5, 7, 5, 3, 3, 4, 2, 4, 4]
for i in range(0,8):
    print(data.count(i))
# Out:
# 2
# 4
# 24
# 25
# 22
# 15
# 6
# 2

# %% [markdown]
# 2. Use `plt.pie(counts)` to produce a pie chart of `data`.

# %%
counts = []
data = [4, 2, 4, 5, 0, 2, 4, 4, 3, 6, 1, 4, 5, 3, 1, 2, 3, 3, 4, 6, 4, 5,2, 6, 5, 2, 3, 3, 4, 4, 2, 1, 4, 3, 2, 3, 6, 7, 3, 3, 3, 4, 2, 4,3, 2, 2, 2, 4, 3, 2, 3, 4, 2, 5, 5, 3, 3, 5, 3, 2, 6, 2, 2, 4, 4,2, 3, 4, 5, 2, 3, 4, 6, 2, 5, 2, 4, 5, 1, 5, 3, 3, 5, 0, 2, 3, 5,3, 2, 2, 5, 7, 5, 3, 3, 4, 2, 4, 4]
for i in range(0,8):
    print(data.count(i))
    counts.append(data.count(i))
plt.pie(counts)
# Out:
# 2
# 4
# 24
# 25
# 22
# 15
# 6
# 2

# %% [markdown]
# 3. Define `labels = [0, 1, 2, 3, 4, 5, 6, 7]` and use `plt.pie(counts, labels = labels, autopct='%1.1f%%')` to produce more informative plot

# %%
counts = []
data = [4, 2, 4, 5, 0, 2, 4, 4, 3, 6, 1, 4, 5, 3, 1, 2, 3, 3, 4, 6, 4, 5,2, 6, 5, 2, 3, 3, 4, 4, 2, 1, 4, 3, 2, 3, 6, 7, 3, 3, 3, 4, 2, 4,3, 2, 2, 2, 4, 3, 2, 3, 4, 2, 5, 5, 3, 3, 5, 3, 2, 6, 2, 2, 4, 4,2, 3, 4, 5, 2, 3, 4, 6, 2, 5, 2, 4, 5, 1, 5, 3, 3, 5, 0, 2, 3, 5,3, 2, 2, 5, 7, 5, 3, 3, 4, 2, 4, 4]
for i in range(0,8):
    print(data.count(i))
    counts.append(data.count(i))
plt.pie(counts, labels=['0','1','2','3','4','5','6','7'], autopct='%1.1f%%')
# Out:
# 2
# 4
# 24
# 25
# 22
# 15
# 6
# 2

# %% [markdown]
# 4. Add an informative title and produce the new plot in the cell below.

# %%
counts = []
data = [4, 2, 4, 5, 0, 2, 4, 4, 3, 6, 1, 4, 5, 3, 1, 2, 3, 3, 4, 6, 4, 5,2, 6, 5, 2, 3, 3, 4, 4, 2, 1, 4, 3, 2, 3, 6, 7, 3, 3, 3, 4, 2, 4,3, 2, 2, 2, 4, 3, 2, 3, 4, 2, 5, 5, 3, 3, 5, 3, 2, 6, 2, 2, 4, 4,2, 3, 4, 5, 2, 3, 4, 6, 2, 5, 2, 4, 5, 1, 5, 3, 3, 5, 0, 2, 3, 5,3, 2, 2, 5, 7, 5, 3, 3, 4, 2, 4, 4]
for i in range(0,8):
    print(data.count(i))
    counts.append(data.count(i))
plt.pie(counts, labels=['0','1','2','3','4','5','6','7'], autopct='%1.1f%%')
plt.title('Distribution of Data Values')
# Out:
# 2
# 4
# 24
# 25
# 22
# 15
# 6
# 2
# Text(0.5, 1.0, 'Distribution of Data Values')

# %% [markdown]
# ### Problem 7
# Using the same data set as above, use `plt.hist()` to produce the histogram of the data set. Add a title and labels.

# %%
counts = []
data = [4, 2, 4, 5, 0, 2, 4, 4, 3, 6, 1, 4, 5, 3, 1, 2, 3, 3, 4, 6, 4, 5,2, 6, 5, 2, 3, 3, 4, 4, 2, 1, 4, 3, 2, 3, 6, 7, 3, 3, 3, 4, 2, 4,3, 2, 2, 2, 4, 3, 2, 3, 4, 2, 5, 5, 3, 3, 5, 3, 2, 6, 2, 2, 4, 4,2, 3, 4, 5, 2, 3, 4, 6, 2, 5, 2, 4, 5, 1, 5, 3, 3, 5, 0, 2, 3, 5,3, 2, 2, 5, 7, 5, 3, 3, 4, 2, 4, 4]
for i in range(0,8):
    print(data.count(i))
    counts.append(data.count(i))
plt.hist(counts, bins=8, edgecolor='black')
plt.title('Histogram of Data Values')
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# 2
# 4
# 24
# 25
# 22
# 15
# 6
# 2
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Problem 8
# Plot a function of your choosing to plot using `plt.scatter()`.

# %%
np.linspace(0,2*np.pi, 100)
x_data = []
y_data = []
for i in np.linspace(0,2*np.pi, 100):
    x_data.append(i)
    y_data.append(np.sin(i)*np.cos(i))
plt.plot(x_data, y_data)
