# %% [markdown]
# # Week 1 Day 4 Lab

# %% [markdown]
# ## Problem 1
# Given
#
# ```python
# animals = ["cat", "dog", "bird", "fish", "horse"]
# ```
#
# Using negative indices, print off `"fish"`.

# %%
conttuple=('cat', 'dog', 'bird','fish','horse')
print(conttuple[-2:-3:-1])
# Out:
# ('fish',)

# %% [markdown]
# ## Problem 2
# Given
#
# ```python
# word = "mathematical computing"
# ```
#
# Print:
#
# - The first character
# - The eighth character
# - The last character

# %%
contlist=("mathematical computing")
print(contlist[0])
print(contlist[7])
print(contlist[21])
# Out:
# m
# t
# g

# %% [markdown]
# ## Problem 3
#
# Given
#
# ```python
#     numbers = [1, 78, 23, 10, 16, 20]
# ```
#
# using slicing (i.e. a start, stop, and a step size) print off the list `[78, 10, 20]`.

# %%
conttuple=[1,78,23,10,16,20]
print(conttuple[1:6:2])
# Out:
# [78, 10, 20]

# %% [markdown]
# ## Problem 4
# Recall the last problem from yesterday's lab:
#
# "If we list all the natural numbers below 10 that are multiples of 3 or 5 we get 3,5,6, and 9. The sum of these multiples is 23.
# Find the sum of all the multiples of 3 or 5 below 1000."
#
# Now try this problem by defining a function that takes a maximum number as the input and outputs the sum of multiples of 3 or 5 below this number. For example, inputting 10 should output 23.

# %%
def my_function(x):
    y = 0
    for i in range(1, x+1):
        if i % 3 == 0 or i % 5 == 0:
            y += i
    return y

my_function(1000)
# Out:
# 234168

# %% [markdown]
# ## Problem 5
#
# Define a function
# ```python
#     rectangle(a, b)
# ```
# that outputs the area of a rectangle given input dimensions `(a,b)`.

# %%
def rectangle(a,b):
    area = a*b
    return area
rectangle(5,10)
# Out:
# 50

# %% [markdown]
# ## Problem 6
#
# Define a function
#
# ```python
#     palindrome(string)
#
# ```
# that takes in a string and outputs whether or not the string is a palindrome. (A palindrome is a word that is the same forward as backward)

# %%
def is_prime(x):
    for i in range(2, int(x**0.5) + 1):
        if x % i == 0:
            return False
    return True


def goldbach(n):
    for i in range(2, n):
        if is_prime(i):
            for j in range(2, n):
                for k in range(2, n):
                    if j % 2 == 1 and is_prime(i) and i + 2 * k**2 == j:
                        return [i, j, k]
    return None


goldbach(300)
# Out:
# [3, 11, 2]
